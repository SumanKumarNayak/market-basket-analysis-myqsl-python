# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("baskets.csv")

# %%
df.head()
# Out:
#    order_id                                             basket
# 0    536365  WHITE HANGING HEART T-LIGHT HOLDER,WHITE METAL...
# 1    536366   HAND WARMER UNION JACK,HAND WARMER RED POLKA DOT
# 2    536367  ASSORTED COLOUR BIRD ORNAMENT,POPPY'S PLAYHOUS...
# 3    536368  JAM MAKING SET WITH JARS,RED COAT RACK PARIS F...
# 4    536369                           BATH BUILDING BLOCK WORD

# %%
df['basket'] = df['basket'].apply(lambda x: x.split(','))
df.head()
# Out:
#    order_id                                             basket
# 0    536365  [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1    536366  [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2    536367  [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3    536368  [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4    536369                         [BATH BUILDING BLOCK WORD]

# %%
# One hot encode transasctions
te = TransactionEncoder()
te_array = te.fit(df['basket']).transform(df['basket'])

basket_df = pd.DataFrame(te_array, columns=te.columns_)
basket_df.head()
# Out:
#            SET 2 TEA TOWELS I LOVE LONDON   \
# 0  False                             False
# 1  False                             False
# 2  False                             False
# 3  False                             False
# 4  False                             False
#
#    3 PIECE SPACEBOY COOKIE CUTTER SET  3 STRIPEY MICE FELTCRAFT  \
# 0                               False                     False
# 1                               False                     False
# 2                               False                     False
# 3                               False                     False
# 4                               False                     False
#
#    3 TIER CAKE TIN GREEN AND CREAM  3 TIER CAKE TIN RED AND CREAM  \
# 0                            False                          False
# 1                            False                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                          False
#
#    5 HOOK HANGER MAGIC TOADSTOOL  60 TEATIME FAIRY CAKE CASES  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    72 SWEETHEART FAIRY CAKE CASES  AIRLINE LOUNGE  ...  \
# 0                           False           False  ...
# 1                           False           False  ...
# 2                           False           False  ...
# 3                           False           False  ...
# 4                           False           False  ...
#
#    WOOD BLACK BOARD ANT WHITE FINISH  WOOD S/3 CABINET ANT WHITE FINISH  \
# 0                              False                              False
# 1                              False                              False
# 2                              False                              False
# 3                              False                              False
# 4                              False                              False
#
#    WOODEN BOX OF DOMINOES  WOODEN FRAME ANTIQUE WHITE   \
# 0                   False                        False
# 1                   False                        False
# 2                   False                        False
# 3                   False                        False
# 4                   False                        False
#
#    WOODEN OWLS LIGHT GARLAND   WOODEN PICTURE FRAME WHITE FINISH  \
# 0                       False                              False
# 1                       False                              False
# 2                       False                              False
# 3                       False                              False
# 4                       False                              False
#
#    YELLOW BREAKFAST CUP AND SAUCER  YELLOW COAT RACK PARIS FASHION  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                            True
# 4                            False                           False
#
#    YOU'RE CONFUSING ME METAL SIGN   ZINC WILLIE WINKIE  CANDLE STICK
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False
#
# [5 rows x 272 columns]

# %%
# Generating frequent details
frequent_itemsets = apriori(
    basket_df,
    min_support=0.05,
    use_colnames=True,
    max_len=2
)

# %%
frequent_itemsets.sort_values(by='support', ascending=False).head()
# Out:
#       support                                           itemsets
# 51   0.162162               (WHITE HANGING HEART T-LIGHT HOLDER)
# 16   0.135135                           (HAND WARMER UNION JACK)
# 44   0.135135                     (SET 7 BABUSHKA NESTING BOXES)
# 28   0.135135              (KNITTED UNION FLAG HOT WATER BOTTLE)
# 120  0.135135  (WHITE HANGING HEART T-LIGHT HOLDER, KNITTED U...

# %%
# Generating Association Rules
rules = association_rules(
    frequent_itemsets,
    metric="lift",
    min_threshold=1
)

rules.head()
# Out:
#                             antecedents                           consequents  \
# 0  (PACK OF 60 PINK PAISLEY CAKE CASES)         (60 TEATIME FAIRY CAKE CASES)
# 1         (60 TEATIME FAIRY CAKE CASES)  (PACK OF 60 PINK PAISLEY CAKE CASES)
# 2     (PACK OF 72 RETROSPOT CAKE CASES)         (60 TEATIME FAIRY CAKE CASES)
# 3         (60 TEATIME FAIRY CAKE CASES)     (PACK OF 72 RETROSPOT CAKE CASES)
# 4           (ALARM CLOCK BAKELIKE RED )          (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.054054            0.081081  0.054054    1.000000  12.333333
# 1            0.081081            0.054054  0.054054    0.666667  12.333333
# 2            0.081081            0.081081  0.054054    0.666667   8.222222
# 3            0.081081            0.081081  0.054054    0.666667   8.222222
# 4            0.081081            0.108108  0.081081    1.000000   9.250000
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.049671         inf       0.971429  0.666667   1.000000
# 1               1.0  0.049671    2.837838       1.000000  0.666667   0.647619
# 2               1.0  0.047480    2.756757       0.955882  0.500000   0.637255
# 3               1.0  0.047480    2.756757       0.955882  0.500000   0.637255
# 4               1.0  0.072316         inf       0.970588  0.750000   1.000000
#
#    kulczynski
# 0    0.833333
# 1    0.833333
# 2    0.666667
# 3    0.666667
# 4    0.875000

# %%
# Top 5 Association Rules
top5 = rules.sort_values(
    by=['lift','support'],
    ascending=False
).head(5)

top5[['antecedents','consequents','support','confidence','lift']]
# Out:
#                       antecedents                  consequents   support  \
# 96       (HAND WARMER OWL DESIGN)  (HAND WARMER RED RETROSPOT)  0.054054
# 97    (HAND WARMER RED RETROSPOT)     (HAND WARMER OWL DESIGN)  0.054054
# 108    (LOVE BUILDING BLOCK WORD)   (HOME BUILDING BLOCK WORD)  0.054054
# 109    (HOME BUILDING BLOCK WORD)   (LOVE BUILDING BLOCK WORD)  0.054054
# 48   (RETRO COFFEE MUGS ASSORTED)      (EDWARDIAN PARASOL RED)  0.081081
#
#      confidence       lift
# 96          1.0  18.500000
# 97          1.0  18.500000
# 108         1.0  18.500000
# 109         1.0  18.500000
# 48          1.0  12.333333
